# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def petit (a,b):
    if(a<b):
        d=a
    else:
        d=0
    return d        # valeur de retour

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = int(input("x :"))
y = int(input("y :"))

# %%
res = petit(a=x,b=y)
print("resultat : " + str(res))
# Out:
# resultat : 13
